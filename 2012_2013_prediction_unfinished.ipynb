# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.covariance import EllipticEnvelope
from xgboost import XGBClassifier

# %%
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',200)

# %% [markdown]
# #### Main approach:
# Extract hospital features in 2012 to predict closure in 2013,hospital features in 2013 to predict closure in 2014
#
#
# #### Dataset:
# Closure status from _Data Shared/Hospital Closure/verified_closure_combined_datereconciled_infoadded_190521 (only closure status used)
#
#
# hospital features from Agency for Healthcare Research and Quality 2012/2013

# %%
dataset_close=pd.read_csv('data\hospital_closure\hospital_closure.csv')
dataset_2012=pd.read_csv('data\hospital_compare\Copy of Agency for Healthcare Research and Quality 2012.csv')
dataset_2013=pd.read_csv('data\hospital_compare\Copy of Agency for Healthcare Research and Quality 2013.csv')

# %% [markdown]
# #### Data Cleaning

# %%
dataset_close['year_close_combined'].value_counts(dropna=False).sort_index()
# Out:
# 2002     1
# 2003     1
# 2004     1
# 2005     1
# 2006     3
# 2007    13
# 2008    16
# 2009    17
# 2010    12
# 2011    13
# 2012    25
# 2013    23
# 2014    24
# 2015    18
# 2016    10
# 2017     7
# Name: year_close_combined, dtype: int64

# %% [markdown]
# 23 hospitals closed in 2013, and 24 hospitals closed in 2014.

# %% [markdown]
# ##### first clean data of Agency for Healthcare Research and Quality 2012

# %%
#create 'Closure' column, where '1' represents closed hospitals in 2013, '0' represents the others
sub_ds=dataset_close[dataset_close['year_close_combined']==2013]
dataset_2012=dataset_2012.rename(columns={'Provider Number':'id'})
dataset_2012['Closure']=dataset_2012.id.apply(lambda x:1 if x in np.array(sub_ds['id']) else 0)

# %%
#drop columns about name and geographic information
dataset_2012.drop(dataset_2012.columns[:10], axis = 1, inplace = True)

# %%
dataset_2012.head()
# Out:
#   Death from serious treatable complications after surgery  \
# 0               No Different than U.S. National Rate
# 1               No Different than U.S. National Rate
# 2               No Different than U.S. National Rate
# 3                          Number of Cases Too Small
# 4                                      Not Available
#
#   Footnote - Death from serious treatable complications after surgery  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Medicare requires hospitals to have at least 2...
# 4  No data are available from the hospital for th...
#
#   Collapsed lung due to medical treatment  \
# 0    No Different than U.S. National Rate
# 1    No Different than U.S. National Rate
# 2    No Different than U.S. National Rate
# 3    No Different than U.S. National Rate
# 4    No Different than U.S. National Rate
#
#   Footnote - Collapsed lung due to medical treatment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#         Breathing failure after surgery  \
# 0  No Different than U.S. National Rate
# 1  No Different than U.S. National Rate
# 2                         Not Available
# 3  No Different than U.S. National Rate
# 4                         Not Available
#
#           Footnote - Breathing failure after surgery  \
# 0                                                NaN
# 1                                                NaN
# 2  No data are available from the hospital for th...
# 3                                                NaN
# 4  No data are available from the hospital for th...
#
#       Serious blood clots after surgery  \
# 0        Better than U.S. National Rate
# 1  No Different than U.S. National Rate
# 2  No Different than U.S. National Rate
# 3  No Different than U.S. National Rate
# 4  No Different than U.S. National Rate
#
#   Footnote - Serious blood clots after surgery  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   A wound that splits open after surgery  \
# 0   No Different than U.S. National Rate
# 1   No Different than U.S. National Rate
# 2   No Different than U.S. National Rate
# 3   No Different than U.S. National Rate
# 4                          Not Available
#
#    Footnote - A wound that splits open after surgery  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  No data are available from the hospital for th...
#
#   Accidental cuts and tears from medical treatment  \
# 0                    Worse than U.S. National Rate
# 1             No Different than U.S. National Rate
# 2                    Worse than U.S. National Rate
# 3             No Different than U.S. National Rate
# 4             No Different than U.S. National Rate
#
#   Footnote - Accidental cuts and tears from medical treatment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                   Serious Complications Footnote - Serious Complications  \
# 0  No Different than U.S. National Rate                              NaN
# 1  No Different than U.S. National Rate                              NaN
# 2  No Different than U.S. National Rate                              NaN
# 3  No Different than U.S. National Rate                              NaN
# 4  No Different than U.S. National Rate                              NaN
#
#   Death after surgery to repair a weakness in the abdominal aorta  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Footnote - Death after surgery to repair a weakness in the abdominal aorta  \
# 0        Suppressed for one or more quarters by CMS.
# 1        Suppressed for one or more quarters by CMS.
# 2        Suppressed for one or more quarters by CMS.
# 3        Suppressed for one or more quarters by CMS.
# 4        Suppressed for one or more quarters by CMS.
#
#   Deaths after admission for broken hip  \
# 0                         Not Available
# 1                         Not Available
# 2                         Not Available
# 3                         Not Available
# 4                         Not Available
#
#   Footnote - Deaths after admission for broken hip  \
# 0      Suppressed for one or more quarters by CMS.
# 1      Suppressed for one or more quarters by CMS.
# 2      Suppressed for one or more quarters by CMS.
# 3      Suppressed for one or more quarters by CMS.
# 4      Suppressed for one or more quarters by CMS.
#
#   Deaths from Certain Conditions    Footnote - Deaths from Certain Conditions  \
# 0                  Not Available  Suppressed for one or more quarters by CMS.
# 1                  Not Available  Suppressed for one or more quarters by CMS.
# 2                  Not Available  Suppressed for one or more quarters by CMS.
# 3                  Not Available  Suppressed for one or more quarters by CMS.
# 4                  Not Available  Suppressed for one or more quarters by CMS.
#
#   Number of Patients - Death from serious treatable complications after surgery  \
# 0                                                157
# 1                                                 29
# 2                                                110
# 3                                                 10
# 4                                      Not Available
#
#   Rate - Death from serious treatable complications after surgery  \
# 0                                             140.58
# 1                                             123.92
# 2                                             146.33
# 3                                      Not Available
# 4                                      Not Available
#
#   Lower Estimate - Death from serious treatable complications after surgery  \
# 0                                             106.16
# 1                                              74.29
# 2                                             106.95
# 3                                      Not Available
# 4                                      Not Available
#
#   Higher Estimate - Death from serious treatable complications after surgery  \
# 0                                                175
# 1                                             173.55
# 2                                             185.71
# 3                                      Not Available
# 4                                      Not Available
#
#   Number of Patients - Collapsed lung due to medical treatment  \
# 0                                              15149
# 1                                               4467
# 2                                               9962
# 3                                               2176
# 4                                                673
#
#   Rate - Collapsed lung due to medical treatment  \
# 0                                           0.32
# 1                                            0.3
# 2                                            0.5
# 3                                            0.3
# 4                                           0.33
#
#   Lower Estimate - Collapsed lung due to medical treatment  \
# 0                                               0.08
# 1                                                  0
# 2                                               0.23
# 3                                                  0
# 4                                                  0
#
#   Higher Estimate - Collapsed lung due to medical treatment  \
# 0                                               0.56
# 1                                               0.65
# 2                                               0.77
# 3                                               0.71
# 4                                               0.76
#
#   Number of Patients - Breathing failure after surgery  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Rate - Breathing failure after surgery  \
# 0                          Not Available
# 1                          Not Available
# 2                          Not Available
# 3                          Not Available
# 4                          Not Available
#
#   Lower Estimate - Breathing failure after surgery  \
# 0                                    Not Available
# 1                                    Not Available
# 2                                    Not Available
# 3                                    Not Available
# 4                                    Not Available
#
#   Higher Estimate - Breathing failure after surgery  \
# 0                                     Not Available
# 1                                     Not Available
# 2                                     Not Available
# 3                                     Not Available
# 4                                     Not Available
#
#   Number of Patients - Serious blood clots after surgery  \
# 0                                               4941
# 1                                                689
# 2                                               2805
# 3                                                173
# 4                                                 28
#
#   Rate - Serious blood clots after surgery  \
# 0                                     1.47
# 1                                      4.7
# 2                                     3.22
# 3                                     6.11
# 4                                     4.52
#
#   Lower Estimate - Serious blood clots after surgery  \
# 0                                                  0
# 1                                               0.98
# 2                                               0.81
# 3                                               1.46
# 4                                                  0
#
#   Higher Estimate - Serious blood clots after surgery  \
# 0                                               3.18
# 1                                               8.42
# 2                                               5.63
# 3                                              10.76
# 4                                                9.6
#
#   Number of Patients - A wound that splits open after surgery  \
# 0                                                393
# 1                                                102
# 2                                                234
# 3                                                 35
# 4                                      Not Available
#
#   Rate - A wound that splits open after surgery  \
# 0                                           0.9
# 1                                          0.69
# 2                                          1.21
# 3                                          0.85
# 4                                 Not Available
#
#   Lower Estimate - A wound that splits open after surgery  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                      Not Available
#
#   Higher Estimate - A wound that splits open after surgery  \
# 0                                               2.37
# 1                                               2.65
# 2                                               2.92
# 3                                               3.03
# 4                                      Not Available
#
#   Number of Patients - Accidental cuts and tears from medical treatment  \
# 0                                              15820
# 1                                               4584
# 2                                              10577
# 3                                               2220
# 4                                                707
#
#   Rate - Accidental cuts and tears from medical treatment  \
# 0                                               3.28
# 1                                                1.5
# 2                                               3.09
# 3                                               1.74
# 4                                                1.9
#
#   Lower Estimate - Accidental cuts and tears from medical treatment  \
# 0                                               2.48
# 1                                                  0
# 2                                               2.11
# 3                                                  0
# 4                                                  0
#
#   Higher Estimate - Accidental cuts and tears from medical treatment  \
# 0                                               4.08
# 1                                               3.03
# 2                                               4.07
# 3                                                3.7
# 4                                               4.21
#
#   Number of Patients - Serious Complications Rate - Serious Complications  \
# 0                              Not Available                Not Available
# 1                              Not Available                Not Available
# 2                              Not Available                Not Available
# 3                              Not Available                Not Available
# 4                              Not Available                Not Available
#
#   Lower Estimate - Serious Complications  \
# 0                          Not Available
# 1                          Not Available
# 2                          Not Available
# 3                          Not Available
# 4                          Not Available
#
#   Higher Estimate - Serious Complications  \
# 0                           Not Available
# 1                           Not Available
# 2                           Not Available
# 3                           Not Available
# 4                           Not Available
#
#   Number of Patients - Death after surgery to repair a weakness in the abdominal aorta  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Rate - Death after surgery to repair a weakness in the abdominal aorta  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Lower Estimate - Death after surgery to repair a weakness in the abdominal aorta  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Higher Estimate - Death after surgery to repair a weakness in the abdominal aorta  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Number of Patients - Deaths after admission for broken hip  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Rate - Deaths after admission for broken hip  \
# 0                                Not Available
# 1                                Not Available
# 2                                Not Available
# 3                                Not Available
# 4                                Not Available
#
#   Lower Estimate - Deaths after admission for broken hip  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Higher Estimate - Deaths after admission for broken hip  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Number of Patients - Deaths from Certain Conditions  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Rate - Deaths from Certain Conditions  \
# 0                         Not Available
# 1                         Not Available
# 2                         Not Available
# 3                         Not Available
# 4                         Not Available
#
#   Lower Estimate - Deaths from Certain Conditions  \
# 0                                   Not Available
# 1                                   Not Available
# 2                                   Not Available
# 3                                   Not Available
# 4                                   Not Available
#
#   Higher Estimate - Deaths from Certain Conditions  Closure
# 0                                    Not Available        0
# 1                                    Not Available        0
# 2                                    Not Available        0
# 3                                    Not Available        0
# 4                                    Not Available        0

# %%
#drop footnote columns
dataset_2012.drop(dataset_2012.columns[dataset_2012.apply(lambda col: 'Footnote' in str(col))], axis=1, inplace = True)

# %%
#drop columns with all 'Not Available' elements
dataset_2012.drop(dataset_2012.columns[dataset_2012.apply(lambda col: (col=='Not Available').all())], axis=1, inplace = True)

# %%
#replace strings in comparison with US national rates
#mapping criteria:
#'No Different than U.S. National Rate','Not Available','Number of Cases Too Small':0
#'Worse than U.S. National Rate': 1
#'Better than U.S. National Rate':2
dataset_2012[['Death from serious treatable complications after surgery','Collapsed lung due to medical treatment','Breathing failure after surgery','Serious blood clots after surgery','A wound that splits open after surgery','Accidental cuts and tears from medical treatment','Serious Complications']]=dataset_2012[['Death from serious treatable complications after surgery','Collapsed lung due to medical treatment','Breathing failure after surgery','Serious blood clots after surgery','A wound that splits open after surgery','Accidental cuts and tears from medical treatment','Serious Complications']].replace({'No Different than U.S. National Rate': 0,' Not Available':0, 'Not Available':0,'Number of Cases Too Small':0,'Worse than U.S. National Rate': 1,'Better than U.S. National Rate':2})

# %%
#replace all missing values by "NaN" 
dataset_2012=dataset_2012.replace({'Not Available':np.nan,' Not Available':np.nan})

# %%
#making all values being able to do numerical calculations
for col in dataset_2012:
    dataset_2012[col]=pd.to_numeric(dataset_2012[col])

# %%
dataset_2012.loc[dataset_2012['Closure']==1]
# Out:
#       Death from serious treatable complications after surgery  \
# 16                                                    0
# 43                                                    0
# 173                                                   0
# 421                                                   0
# 478                                                   0
# 565                                                   0
# 1141                                                  0
# 1653                                                  0
# 2710                                                  0
# 2837                                                  0
# 2901                                                  0
# 3085                                                  0
# 3914                                                  0
# 4006                                                  0
# 4030                                                  0
# 4045                                                  0
# 4052                                                  0
# 4197                                                  0
# 4584                                                  0
#
#       Collapsed lung due to medical treatment  \
# 16                                          0
# 43                                          0
# 173                                         0
# 421                                         0
# 478                                         0
# 565                                         0
# 1141                                        0
# 1653                                        0
# 2710                                        0
# 2837                                        0
# 2901                                        0
# 3085                                        0
# 3914                                        0
# 4006                                        0
# 4030                                        0
# 4045                                        0
# 4052                                        0
# 4197                                        0
# 4584                                        0
#
#       Breathing failure after surgery  Serious blood clots after surgery  \
# 16                                  0                                  0
# 43                                  0                                  0
# 173                                 0                                  0
# 421                                 0                                  0
# 478                                 0                                  0
# 565                                 0                                  0
# 1141                                0                                  0
# 1653                                0                                  0
# 2710                                0                                  0
# 2837                                0                                  0
# 2901                                0                                  0
# 3085                                0                                  0
# 3914                                0                                  0
# 4006                                0                                  0
# 4030                                0                                  0
# 4045                                0                                  0
# 4052                                0                                  0
# 4197                                0                                  0
# 4584                                0                                  0
#
#       A wound that splits open after surgery  \
# 16                                         0
# 43                                         0
# 173                                        0
# 421                                        0
# 478                                        0
# 565                                        0
# 1141                                       0
# 1653                                       0
# 2710                                       0
# 2837                                       0
# 2901                                       0
# 3085                                       0
# 3914                                       0
# 4006                                       0
# 4030                                       0
# 4045                                       0
# 4052                                       0
# 4197                                       0
# 4584                                       0
#
#       Accidental cuts and tears from medical treatment  Serious Complications  \
# 16                                                   0                      0
# 43                                                   0                      0
# 173                                                  0                      0
# 421                                                  0                      0
# 478                                                  0                      0
# 565                                                  0                      0
# 1141                                                 0                      0
# 1653                                                 0                      0
# 2710                                                 0                      0
# 2837                                                 2                      0
# 2901                                                 0                      0
# 3085                                                 0                      0
# 3914                                                 0                      0
# 4006                                                 0                      0
# 4030                                                 0                      0
# 4045                                                 0                      0
# 4052                                                 0                      0
# 4197                                                 0                      0
# 4584                                                 0                      0
#
#       Number of Patients - Death from serious treatable complications after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                                49.0
# 421                                                 NaN
# 478                                                13.0
# 565                                                 NaN
# 1141                                               14.0
# 1653                                                NaN
# 2710                                                5.0
# 2837                                               28.0
# 2901                                               25.0
# 3085                                               35.0
# 3914                                                NaN
# 4006                                                8.0
# 4030                                                NaN
# 4045                                                NaN
# 4052                                               47.0
# 4197                                                5.0
# 4584                                                NaN
#
#       Rate - Death from serious treatable complications after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                              140.32
# 421                                                 NaN
# 478                                                 NaN
# 565                                                 NaN
# 1141                                                NaN
# 1653                                                NaN
# 2710                                                NaN
# 2837                                             112.24
# 2901                                             114.91
# 3085                                             107.36
# 3914                                                NaN
# 4006                                                NaN
# 4030                                                NaN
# 4045                                                NaN
# 4052                                             108.72
# 4197                                                NaN
# 4584                                                NaN
#
#       Lower Estimate - Death from serious treatable complications after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                               96.20
# 421                                                 NaN
# 478                                                 NaN
# 565                                                 NaN
# 1141                                                NaN
# 1653                                                NaN
# 2710                                                NaN
# 2837                                              65.22
# 2901                                              63.95
# 3085                                              59.85
# 3914                                                NaN
# 4006                                                NaN
# 4030                                                NaN
# 4045                                                NaN
# 4052                                              63.29
# 4197                                                NaN
# 4584                                                NaN
#
#       Higher Estimate - Death from serious treatable complications after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                              184.44
# 421                                                 NaN
# 478                                                 NaN
# 565                                                 NaN
# 1141                                                NaN
# 1653                                                NaN
# 2710                                                NaN
# 2837                                             159.26
# 2901                                             165.87
# 3085                                             154.87
# 3914                                                NaN
# 4006                                                NaN
# 4030                                                NaN
# 4045                                                NaN
# 4052                                             154.15
# 4197                                                NaN
# 4584                                                NaN
#
#       Number of Patients - Collapsed lung due to medical treatment  \
# 16                                                575.0
# 43                                                571.0
# 173                                              1674.0
# 421                                               180.0
# 478                                              1801.0
# 565                                               250.0
# 1141                                             2654.0
# 1653                                             2178.0
# 2710                                             1187.0
# 2837                                             5074.0
# 2901                                             2144.0
# 3085                                             5489.0
# 3914                                              713.0
# 4006                                             1393.0
# 4030                                              994.0
# 4045                                              373.0
# 4052                                             3453.0
# 4197                                             2590.0
# 4584                                              877.0
#
#       Rate - Collapsed lung due to medical treatment  \
# 16                                              0.34
# 43                                              0.32
# 173                                             0.34
# 421                                             0.34
# 478                                             0.30
# 565                                             0.33
# 1141                                            0.28
# 1653                                            0.31
# 2710                                            0.30
# 2837                                            0.37
# 2901                                            0.39
# 3085                                            0.20
# 3914                                            0.33
# 4006                                            0.31
# 4030                                            0.33
# 4045                                            0.34
# 4052                                            0.35
# 4197                                            0.29
# 4584                                            0.33
#
#       Lower Estimate - Collapsed lung due to medical treatment  \
# 16                                                 0.00
# 43                                                 0.00
# 173                                                0.00
# 421                                                0.00
# 478                                                0.00
# 565                                                0.00
# 1141                                               0.00
# 1653                                               0.00
# 2710                                               0.00
# 2837                                               0.06
# 2901                                               0.00
# 3085                                               0.00
# 3914                                               0.00
# 4006                                               0.00
# 4030                                               0.00
# 4045                                               0.00
# 4052                                               0.02
# 4197                                               0.00
# 4584                                               0.00
#
#       Higher Estimate - Collapsed lung due to medical treatment  \
# 16                                                 0.77
# 43                                                 0.75
# 173                                                0.71
# 421                                                0.77
# 478                                                0.71
# 565                                                0.76
# 1141                                               0.67
# 1653                                               0.72
# 2710                                               0.71
# 2837                                               0.68
# 2901                                               0.78
# 3085                                               0.53
# 3914                                               0.76
# 4006                                               0.72
# 4030                                               0.76
# 4045                                               0.77
# 4052                                               0.68
# 4197                                               0.70
# 4584                                               0.76
#
#       Number of Patients - Serious blood clots after surgery  \
# 16                                                  NaN
# 43                                                  3.0
# 173                                               628.0
# 421                                                 8.0
# 478                                               194.0
# 565                                                13.0
# 1141                                              318.0
# 1653                                               39.0
# 2710                                              137.0
# 2837                                              739.0
# 2901                                              435.0
# 3085                                              850.0
# 3914                                                NaN
# 4006                                               87.0
# 4030                                                NaN
# 4045                                                NaN
# 4052                                              771.0
# 4197                                               84.0
# 4584                                              101.0
#
#       Rate - Serious blood clots after surgery  \
# 16                                         NaN
# 43                                         NaN
# 173                                       4.47
# 421                                        NaN
# 478                                       3.74
# 565                                        NaN
# 1141                                      3.44
# 1653                                      4.45
# 2710                                      3.98
# 2837                                      7.54
# 2901                                      5.97
# 3085                                      2.41
# 3914                                       NaN
# 4006                                      4.14
# 4030                                       NaN
# 4045                                       NaN
# 4052                                      5.12
# 4197                                      4.16
# 4584                                      4.19
#
#       Lower Estimate - Serious blood clots after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                                0.49
# 421                                                 NaN
# 478                                                0.00
# 565                                                 NaN
# 1141                                               0.00
# 1653                                               0.00
# 2710                                               0.00
# 2837                                               4.23
# 2901                                               2.09
# 3085                                               0.00
# 3914                                                NaN
# 4006                                               0.00
# 4030                                                NaN
# 4045                                                NaN
# 4052                                               1.53
# 4197                                               0.00
# 4584                                               0.00
#
#       Higher Estimate - Serious blood clots after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                                8.45
# 421                                                 NaN
# 478                                                8.37
# 565                                                 NaN
# 1141                                               7.87
# 1653                                               9.49
# 2710                                               8.74
# 2837                                              10.85
# 2901                                               9.85
# 3085                                               5.64
# 3914                                                NaN
# 4006                                               9.00
# 4030                                                NaN
# 4045                                                NaN
# 4052                                               8.71
# 4197                                               9.04
# 4584                                               9.07
#
#       Number of Patients - A wound that splits open after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                                32.0
# 421                                                 3.0
# 478                                                24.0
# 565                                                 5.0
# 1141                                               78.0
# 1653                                               14.0
# 2710                                               26.0
# 2837                                              146.0
# 2901                                               58.0
# 3085                                              143.0
# 3914                                                NaN
# 4006                                               28.0
# 4030                                                NaN
# 4045                                                NaN
# 4052                                               86.0
# 4197                                               28.0
# 4584                                               21.0
#
#       Rate - A wound that splits open after surgery  \
# 16                                              NaN
# 43                                              NaN
# 173                                            0.86
# 421                                             NaN
# 478                                             NaN
# 565                                             NaN
# 1141                                           0.74
# 1653                                            NaN
# 2710                                           0.87
# 2837                                           1.40
# 2901                                           0.79
# 3085                                           0.62
# 3914                                            NaN
# 4006                                           0.87
# 4030                                            NaN
# 4045                                            NaN
# 4052                                           1.66
# 4197                                           0.85
# 4584                                            NaN
#
#       Lower Estimate - A wound that splits open after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                                 0.0
# 421                                                 NaN
# 478                                                 NaN
# 565                                                 NaN
# 1141                                                0.0
# 1653                                                NaN
# 2710                                                0.0
# 2837                                                0.0
# 2901                                                0.0
# 3085                                                0.0
# 3914                                                NaN
# 4006                                                0.0
# 4030                                                NaN
# 4045                                                NaN
# 4052                                                0.0
# 4197                                                0.0
# 4584                                                NaN
#
#       Higher Estimate - A wound that splits open after surgery  \
# 16                                                  NaN
# 43                                                  NaN
# 173                                                3.06
# 421                                                 NaN
# 478                                                 NaN
# 565                                                 NaN
# 1141                                               2.78
# 1653                                                NaN
# 2710                                               3.08
# 2837                                               3.24
# 2901                                               2.89
# 3085                                               2.48
# 3914                                                NaN
# 4006                                               3.08
# 4030                                                NaN
# 4045                                                NaN
# 4052                                               3.66
# 4197                                               3.05
# 4584                                                NaN
#
#       Number of Patients - Accidental cuts and tears from medical treatment  \
# 16                                                594.0
# 43                                                576.0
# 173                                              1900.0
# 421                                               181.0
# 478                                              1842.0
# 565                                               252.0
# 1141                                             2677.0
# 1653                                             2223.0
# 2710                                             1227.0
# 2837                                             5157.0
# 2901                                             2222.0
# 3085                                             5654.0
# 3914                                              738.0
# 4006                                             1485.0
# 4030                                             1053.0
# 4045                                              377.0
# 4052                                             3729.0
# 4197                                             2676.0
# 4584                                              907.0
#
#       Rate - Accidental cuts and tears from medical treatment  \
# 16                                                 1.95
# 43                                                 1.94
# 173                                                2.08
# 421                                                1.97
# 478                                                1.46
# 565                                                1.95
# 1141                                               1.93
# 1653                                               1.62
# 2710                                               1.88
# 2837                                               0.66
# 2901                                               1.83
# 3085                                               1.88
# 3914                                               1.95
# 4006                                               1.99
# 4030                                               1.89
# 4045                                               1.99
# 4052                                               1.24
# 4197                                               1.41
# 4584                                               1.56
#
#       Lower Estimate - Accidental cuts and tears from medical treatment  \
# 16                                                 0.00
# 43                                                 0.00
# 173                                                0.49
# 421                                                0.00
# 478                                                0.00
# 565                                                0.00
# 1141                                               0.05
# 1653                                               0.00
# 2710                                               0.00
# 2837                                               0.00
# 2901                                               0.01
# 3085                                               0.45
# 3914                                               0.00
# 4006                                               0.00
# 4030                                               0.00
# 4045                                               0.00
# 4052                                               0.00
# 4197                                               0.00
# 4584                                               0.00
#
#       Higher Estimate - Accidental cuts and tears from medical treatment  \
# 16                                                 4.30
# 43                                                 4.27
# 173                                                3.67
# 421                                                4.32
# 478                                                3.48
# 565                                                4.28
# 1141                                               3.81
# 1653                                               3.76
# 2710                                               3.92
# 2837                                               2.01
# 2901                                               3.65
# 3085                                               3.31
# 3914                                               4.28
# 4006                                               4.09
# 4030                                               4.20
# 4045                                               4.36
# 4052                                               2.75
# 4197                                               3.41
# 4584                                               3.66
#
#       Closure
# 16          1
# 43          1
# 173         1
# 421         1
# 478         1
# 565         1
# 1141        1
# 1653        1
# 2710        1
# 2837        1
# 2901        1
# 3085        1
# 3914        1
# 4006        1
# 4030        1
# 4045        1
# 4052        1
# 4197        1
# 4584        1

# %%
#drop columns with too many NaN values in closed hospital features
dataset_2012.drop(dataset_2012.columns[dataset_2012.apply(lambda col: '- Death from serious treatable complications after surgery' in str(col))], axis=1, inplace = True)
dataset_2012.drop(dataset_2012.columns[dataset_2012.apply(lambda col: '- A wound that splits open after surgery' in str(col))], axis=1, inplace = True)
dataset_2012.drop(dataset_2012.columns[dataset_2012.apply(lambda col: '- Serious blood clots after surgery' in str(col))], axis=1, inplace = True)
dataset_2012.drop(dataset_2012.columns[dataset_2012.apply(lambda col: 'Breathing failure after surgery' in str(col))], axis=1, inplace = True)

# %%
#closed hospital features now with no NaN values 
dataset_2012.loc[dataset_2012['Closure']==1]
# Out:
#       Death from serious treatable complications after surgery  \
# 16                                                    0
# 43                                                    0
# 173                                                   0
# 421                                                   0
# 478                                                   0
# 565                                                   0
# 1141                                                  0
# 1653                                                  0
# 2710                                                  0
# 2837                                                  0
# 2901                                                  0
# 3085                                                  0
# 3914                                                  0
# 4006                                                  0
# 4030                                                  0
# 4045                                                  0
# 4052                                                  0
# 4197                                                  0
# 4584                                                  0
#
#       Collapsed lung due to medical treatment  \
# 16                                          0
# 43                                          0
# 173                                         0
# 421                                         0
# 478                                         0
# 565                                         0
# 1141                                        0
# 1653                                        0
# 2710                                        0
# 2837                                        0
# 2901                                        0
# 3085                                        0
# 3914                                        0
# 4006                                        0
# 4030                                        0
# 4045                                        0
# 4052                                        0
# 4197                                        0
# 4584                                        0
#
#       Serious blood clots after surgery  \
# 16                                    0
# 43                                    0
# 173                                   0
# 421                                   0
# 478                                   0
# 565                                   0
# 1141                                  0
# 1653                                  0
# 2710                                  0
# 2837                                  0
# 2901                                  0
# 3085                                  0
# 3914                                  0
# 4006                                  0
# 4030                                  0
# 4045                                  0
# 4052                                  0
# 4197                                  0
# 4584                                  0
#
#       A wound that splits open after surgery  \
# 16                                         0
# 43                                         0
# 173                                        0
# 421                                        0
# 478                                        0
# 565                                        0
# 1141                                       0
# 1653                                       0
# 2710                                       0
# 2837                                       0
# 2901                                       0
# 3085                                       0
# 3914                                       0
# 4006                                       0
# 4030                                       0
# 4045                                       0
# 4052                                       0
# 4197                                       0
# 4584                                       0
#
#       Accidental cuts and tears from medical treatment  Serious Complications  \
# 16                                                   0                      0
# 43                                                   0                      0
# 173                                                  0                      0
# 421                                                  0                      0
# 478                                                  0                      0
# 565                                                  0                      0
# 1141                                                 0                      0
# 1653                                                 0                      0
# 2710                                                 0                      0
# 2837                                                 2                      0
# 2901                                                 0                      0
# 3085                                                 0                      0
# 3914                                                 0                      0
# 4006                                                 0                      0
# 4030                                                 0                      0
# 4045                                                 0                      0
# 4052                                                 0                      0
# 4197                                                 0                      0
# 4584                                                 0                      0
#
#       Number of Patients - Collapsed lung due to medical treatment  \
# 16                                                575.0
# 43                                                571.0
# 173                                              1674.0
# 421                                               180.0
# 478                                              1801.0
# 565                                               250.0
# 1141                                             2654.0
# 1653                                             2178.0
# 2710                                             1187.0
# 2837                                             5074.0
# 2901                                             2144.0
# 3085                                             5489.0
# 3914                                              713.0
# 4006                                             1393.0
# 4030                                              994.0
# 4045                                              373.0
# 4052                                             3453.0
# 4197                                             2590.0
# 4584                                              877.0
#
#       Rate - Collapsed lung due to medical treatment  \
# 16                                              0.34
# 43                                              0.32
# 173                                             0.34
# 421                                             0.34
# 478                                             0.30
# 565                                             0.33
# 1141                                            0.28
# 1653                                            0.31
# 2710                                            0.30
# 2837                                            0.37
# 2901                                            0.39
# 3085                                            0.20
# 3914                                            0.33
# 4006                                            0.31
# 4030                                            0.33
# 4045                                            0.34
# 4052                                            0.35
# 4197                                            0.29
# 4584                                            0.33
#
#       Lower Estimate - Collapsed lung due to medical treatment  \
# 16                                                 0.00
# 43                                                 0.00
# 173                                                0.00
# 421                                                0.00
# 478                                                0.00
# 565                                                0.00
# 1141                                               0.00
# 1653                                               0.00
# 2710                                               0.00
# 2837                                               0.06
# 2901                                               0.00
# 3085                                               0.00
# 3914                                               0.00
# 4006                                               0.00
# 4030                                               0.00
# 4045                                               0.00
# 4052                                               0.02
# 4197                                               0.00
# 4584                                               0.00
#
#       Higher Estimate - Collapsed lung due to medical treatment  \
# 16                                                 0.77
# 43                                                 0.75
# 173                                                0.71
# 421                                                0.77
# 478                                                0.71
# 565                                                0.76
# 1141                                               0.67
# 1653                                               0.72
# 2710                                               0.71
# 2837                                               0.68
# 2901                                               0.78
# 3085                                               0.53
# 3914                                               0.76
# 4006                                               0.72
# 4030                                               0.76
# 4045                                               0.77
# 4052                                               0.68
# 4197                                               0.70
# 4584                                               0.76
#
#       Number of Patients - Accidental cuts and tears from medical treatment  \
# 16                                                594.0
# 43                                                576.0
# 173                                              1900.0
# 421                                               181.0
# 478                                              1842.0
# 565                                               252.0
# 1141                                             2677.0
# 1653                                             2223.0
# 2710                                             1227.0
# 2837                                             5157.0
# 2901                                             2222.0
# 3085                                             5654.0
# 3914                                              738.0
# 4006                                             1485.0
# 4030                                             1053.0
# 4045                                              377.0
# 4052                                             3729.0
# 4197                                             2676.0
# 4584                                              907.0
#
#       Rate - Accidental cuts and tears from medical treatment  \
# 16                                                 1.95
# 43                                                 1.94
# 173                                                2.08
# 421                                                1.97
# 478                                                1.46
# 565                                                1.95
# 1141                                               1.93
# 1653                                               1.62
# 2710                                               1.88
# 2837                                               0.66
# 2901                                               1.83
# 3085                                               1.88
# 3914                                               1.95
# 4006                                               1.99
# 4030                                               1.89
# 4045                                               1.99
# 4052                                               1.24
# 4197                                               1.41
# 4584                                               1.56
#
#       Lower Estimate - Accidental cuts and tears from medical treatment  \
# 16                                                 0.00
# 43                                                 0.00
# 173                                                0.49
# 421                                                0.00
# 478                                                0.00
# 565                                                0.00
# 1141                                               0.05
# 1653                                               0.00
# 2710                                               0.00
# 2837                                               0.00
# 2901                                               0.01
# 3085                                               0.45
# 3914                                               0.00
# 4006                                               0.00
# 4030                                               0.00
# 4045                                               0.00
# 4052                                               0.00
# 4197                                               0.00
# 4584                                               0.00
#
#       Higher Estimate - Accidental cuts and tears from medical treatment  \
# 16                                                 4.30
# 43                                                 4.27
# 173                                                3.67
# 421                                                4.32
# 478                                                3.48
# 565                                                4.28
# 1141                                               3.81
# 1653                                               3.76
# 2710                                               3.92
# 2837                                               2.01
# 2901                                               3.65
# 3085                                               3.31
# 3914                                               4.28
# 4006                                               4.09
# 4030                                               4.20
# 4045                                               4.36
# 4052                                               2.75
# 4197                                               3.41
# 4584                                               3.66
#
#       Closure
# 16          1
# 43          1
# 173         1
# 421         1
# 478         1
# 565         1
# 1141        1
# 1653        1
# 2710        1
# 2837        1
# 2901        1
# 3085        1
# 3914        1
# 4006        1
# 4030        1
# 4045        1
# 4052        1
# 4197        1
# 4584        1

# %%
#now almost all rows having NaN values have more than 4 NaN values (only 3 exception rows), so drop them all
dataset_2012.dropna(inplace=True)

# %% [markdown]
# ##### apply the same steps above to  Agency for Healthcare Research and Quality 2013

# %%
#apply the same steps above to  Agency for Healthcare Research and Quality 2013
sub_ds2=dataset_close[dataset_close['year_close_combined']==2014]
dataset_2013=dataset_2013.rename(columns={'Provider Number':'id'})
dataset_2013['Closure']=dataset_2013.id.apply(lambda x:1 if x in np.array(sub_ds2['id']) else 0)
dataset_2013.drop(dataset_2013.columns[:10], axis = 1, inplace = True)

# %%
dataset_2013.drop(dataset_2013.columns[dataset_2013.apply(lambda col: 'Footnote' in str(col))], axis=1, inplace = True)
dataset_2013.drop(dataset_2013.columns[dataset_2013.apply(lambda col: (col=='Not Available').all())], axis=1, inplace = True)
dataset_2013[['Death from serious treatable complications after surgery','Collapsed lung due to medical treatment','Serious blood clots after surgery','A wound that splits open after surgery','Accidental cuts and tears from medical treatment','Serious Complications']]=dataset_2013[['Death from serious treatable complications after surgery','Collapsed lung due to medical treatment','Serious blood clots after surgery','A wound that splits open after surgery','Accidental cuts and tears from medical treatment','Serious Complications']].replace({'No Different than U.S. National Rate': 0,' Not Available':0, 'Not Available':0,'Number of Cases Too Small':0,'Worse than U.S. National Rate': 1,'Better than U.S. National Rate':2})
dataset_2013=dataset_2013.replace({'Not Available':np.nan,' Not Available':np.nan})
for col in dataset_2013:
    dataset_2013[col]=pd.to_numeric(dataset_2013[col])

# %%
dataset_2013.drop(dataset_2013.columns[dataset_2013.apply(lambda col: '- Death from serious treatable complications after surgery' in str(col))], axis=1, inplace = True)
dataset_2013.drop(dataset_2013.columns[dataset_2013.apply(lambda col: '- A wound that splits open after surgery' in str(col))], axis=1, inplace = True)
dataset_2013.drop(dataset_2013.columns[dataset_2013.apply(lambda col: '- Serious blood clots after surgery' in str(col))], axis=1, inplace = True)
#drop the columns that did not appear in dataset_2012  
dataset_2013.drop(dataset_2013.columns[dataset_2013.apply(lambda col: '- Serious Complications' in str(col))], axis=1, inplace = True)
dataset_2013.dropna(inplace=True)

# %% [markdown]
# now the datasets of 2012 and 2013 have same size of features, we can merge them into a larger dataset, and split it in training set and test set

# %%
dataset=pd.concat([dataset_2012,dataset_2013])
train, test = train_test_split(dataset, test_size=0.2)

# %%
X_train = train.drop("Closure", axis=1)
Y_train = train["Closure"]
X_test  = test.drop("Closure", axis=1).copy()
Y_test  = test["Closure"]
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((5262, 14), (5262,), (1316, 14), (1316,))

# %% [markdown]
# ##### Logistic Regression

# %%
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = cross_val_predict(logreg, X_train, Y_train, cv=10)
acc_log = logreg.score(X_train, Y_train) * 100
acc_log_t = logreg.score(X_test, Y_test) * 100
print('training score:' +str(acc_log))
print('test score:' +str(acc_log_t))
confusion_matrix(Y_train, Y_pred)
# Out:
# training score:99.41087039148613
# test score:99.46808510638297
# array([[5231,    0],
#        [  31,    0]], dtype=int64)

# %% [markdown]
# ##### SVM

# %%
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = svc.score(X_train, Y_train) * 100
acc_svc_t = svc.score(X_test, Y_test) * 100
print('training score:' +str(acc_svc))
print('test score:' +str(acc_svc_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# training score:99.41087039148613
# test score:99.46808510638297
# array([[1309,    0],
#        [   7,    0]], dtype=int64)

# %% [markdown]
# ##### k-NN

# %%
knn = KNeighborsClassifier(n_neighbors = X_train.shape[0])
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = knn.score(X_train, Y_train) * 100
acc_knn_t = knn.score(X_test, Y_test) * 100
print('training score:' +str(acc_knn))
print('test score:' +str(acc_knn_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# training score:99.41087039148613
# test score:99.46808510638297
# array([[1309,    0],
#        [   7,    0]], dtype=int64)

# %% [markdown]
# ##### Gaussian Naive Bayes

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, Y_train)
Y_pred = gaussian.predict(X_test)
acc_gaussian = gaussian.score(X_train, Y_train) * 100
acc_gaussian_t = gaussian.score(X_test, Y_test) * 100
print('training score:' +str(acc_gaussian))
print('test score:' +str(acc_gaussian_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# training score:64.36716077537058
# test score:63.525835866261396
# array([[830, 479],
#        [  1,   6]], dtype=int64)

# %% [markdown]
# ##### Perceptron

# %%
perceptron = Perceptron()
perceptron.fit(X_train, Y_train)
Y_pred = perceptron.predict(X_test)
acc_perceptron = perceptron.score(X_train, Y_train) * 100
acc_perceptron_t = perceptron.score(X_test, Y_test) * 100
print('training score:' +str(acc_perceptron))
print('test score:' +str(acc_perceptron_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# training score:99.41087039148613
# test score:99.46808510638297
# array([[1309,    0],
#        [   7,    0]], dtype=int64)

# %% [markdown]
# ##### Linear SVM

# %%
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
Y_pred = linear_svc.predict(X_test)
acc_linear_svc = linear_svc.score(X_train, Y_train) * 100
acc_linear_svc_t = linear_svc.score(X_test, Y_test) * 100
print('training score:' +str(acc_linear_svc))
print('test score:' +str(acc_linear_svc_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# training score:93.48156594450779
# test score:94.30091185410335
# array([[1241,   68],
#        [   7,    0]], dtype=int64)

# %% [markdown]
# ##### linear classifier with stochastic gradient descent

# %%
sgd = SGDClassifier()
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_test)
acc_sgd = sgd.score(X_train, Y_train) * 100
acc_sgd_t = sgd.score(X_test, Y_test) * 100
print('training score:' +str(acc_sgd))
print('test score:' +str(acc_sgd_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# training score:99.41087039148613
# test score:99.46808510638297
# array([[1309,    0],
#        [   7,    0]], dtype=int64)

# %% [markdown]
# ##### decision tree

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = decision_tree.score(X_train, Y_train) * 100
acc_decision_tree_t = decision_tree.score(X_test, Y_test) * 100
print('training score:' +str(acc_decision_tree))
print('test score:' +str(acc_decision_tree_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# training score:100.0
# test score:98.93617021276596
# array([[1302,    7],
#        [   7,    0]], dtype=int64)

# %% [markdown]
# ##### random forest

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = random_forest.score(X_train, Y_train) * 100
acc_random_forest_t = random_forest.score(X_test, Y_test) * 100
print('training score:' +str(acc_random_forest))
print('test score:' +str(acc_random_forest_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# training score:100.0
# test score:99.46808510638297
# array([[1309,    0],
#        [   7,    0]], dtype=int64)

# %% [markdown]
# ##### XGBoost

# %%
xgboost = XGBClassifier()
xgboost.fit(X_train, Y_train)
Y_pred = xgboost.predict(X_test)
xgboost.score(X_train, Y_train)
acc_xgboost = xgboost.score(X_train, Y_train) * 100
acc_xgboost_t = xgboost.score(X_test, Y_test) * 100
print('training score:' +str(acc_xgboost))
print('test score:' +str(acc_xgboost_t))
confusion_matrix(Y_test, Y_pred)
# Out:
# [08:29:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# training score:99.8859749144812
# test score:99.46808510638297
# array([[1309,    0],
#        [   7,    0]], dtype=int64)

# %% [markdown]
# #### One-Class Classification for unbalanced Data
# We can see that only a very small percentage of hospitals are closed, so the data are very unbalanced. Three algorithms below can regard the small percentage class as outliers.

# %% [markdown]
# ##### Isolation Forest

# %%
isolation_forest= IsolationForest(contamination=0.00575, behaviour='new')
X_train_= X_train[Y_train==0]
isolation_forest.fit(X_train_)
Y_pred = isolation_forest.predict(X_train)
Y_pred[Y_pred == 1] = 0
Y_pred[Y_pred == -1] = 1
confusion_matrix(Y_train, Y_pred)
# Out:
# array([[5200,   31],
#        [  31,    0]], dtype=int64)

# %% [markdown]
# ##### one-class SVM

# %%
one_class_SVM= OneClassSVM(gamma='scale', nu=0.00575)
X_train_= X_train[Y_train==0]
one_class_SVM.fit(X_train_)
Y_pred = one_class_SVM.predict(X_train)
Y_pred[Y_pred == 1] = 0
Y_pred[Y_pred == -1] = 1
confusion_matrix(Y_train, Y_pred)
# Out:
# array([[5199,   32],
#        [  31,    0]], dtype=int64)

# %% [markdown]
# ##### Minimum Covariance Determinant

# %%
MCD= EllipticEnvelope(contamination=0.00575)
X_train_= X_train[Y_train==0]
MCD.fit(X_train_)
Y_pred = MCD.predict(X_train)
Y_pred[Y_pred == 1] = 0
Y_pred[Y_pred == -1] = 1
confusion_matrix(Y_train, Y_pred)
# Out:
# array([[5200,   31],
#        [  31,    0]], dtype=int64)

# %% [markdown]
# ##### Comparison of supervised learning algorithms above

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree', 'XGBoost'],
    'Training Score': [acc_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_linear_svc, acc_decision_tree,acc_xgboost],
    'Test Score': [acc_svc_t, acc_knn_t, acc_log_t, 
              acc_random_forest_t, acc_gaussian_t, acc_perceptron_t, 
              acc_sgd_t, acc_linear_svc_t, acc_decision_tree_t,acc_xgboost_t]})
models.sort_values(by='Test Score', ascending=False)
# Out:
#                         Model  Training Score  Test Score
# 0     Support Vector Machines       99.410870   99.468085
# 1                         KNN       99.410870   99.468085
# 2         Logistic Regression       99.410870   99.468085
# 3               Random Forest      100.000000   99.468085
# 5                  Perceptron       99.410870   99.468085
# 6  Stochastic Gradient Decent       99.410870   99.468085
# 9                     XGBoost       99.885975   99.468085
# 8               Decision Tree      100.000000   98.936170
# 7                  Linear SVC       93.481566   94.300912
# 4                 Naive Bayes       64.367161   63.525836
